# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpaches
import matplotlib as mpl
import backtrader as bt 
import yfinance as yf



from termcolor import colored as cl # Color formatting for output in terminal

from datetime import datetime

# %%
stock = 'BA'
startdate = '2021-08-10'
enddate = '2022-08-11'


df = yf.download(stock,start=startdate, end=enddate,progress=False)
ba = yf.download(stock,start=startdate, end=enddate,progress=False)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-08-09  229.000000  233.570007  226.889999  232.270004  232.270004
# 2021-08-10  231.970001  236.850006  231.619995  235.779999  235.779999
# 2021-08-11  236.610001  239.589996  234.580002  239.490005  239.490005
# 2021-08-12  240.000000  241.149994  236.509995  238.179993  238.179993
# 2021-08-13  238.009995  239.690002  234.279999  234.460007  234.460007
#
#              Volume
# Date
# 2021-08-09  8358600
# 2021-08-10  9603500
# 2021-08-11  9664000
# 2021-08-12  6810000
# 2021-08-13  6390300

# %%
df = df.loc[:,['Adj Close']]
df.rename(columns={'Adj Close':'adj_close'}, inplace=True)# inplace meaning
df['simple_rtn']=df.adj_close.pct_change()# meaning 
df['log_rtn']=np.log(df.adj_close/df.adj_close.shift(1))

# %%
df.head()
# Out:
#              adj_close  simple_rtn   log_rtn
# Date
# 2021-08-09  232.270004         NaN       NaN
# 2021-08-10  235.779999    0.015112  0.014999
# 2021-08-11  239.490005    0.015735  0.015613
# 2021-08-12  238.179993   -0.005470 -0.005485
# 2021-08-13  234.460007   -0.015618 -0.015742

# %%
#Following charts present the prices of MS as well as its simple and logarithmic
fig,ax= plt.subplots(3,1 ,figsize=(24,20),sharex=False)
plt.subplots_adjust(bottom=0.1,  top=0.9, hspace=0.4)


df.adj_close.plot(ax=ax[0],fontsize=16)


ax[0].set_title('MS time series',fontsize=20,color='brown')
ax[0].set_ylabel('Stock price ($)',fontsize=20,color='brown')
ax[0].set_xlabel('Date',fontsize=20,color='brown')


df.simple_rtn.plot(ax=ax[1],fontsize=16)

ax[1].set_title('MS time series',fontsize=20,color='brown')
ax[1].set_ylabel('Simple return (%)',fontsize=20,color='brown')
ax[1].set_xlabel('Date',fontsize=20,color='brown')

df.log_rtn.plot(ax=ax[2],fontsize=16)
ax[2].set_title('MS time series',fontsize=20,color='brown')
ax[2].set_ylabel('Log return (%)',fontsize=20,color='brown')
ax[2].set_xlabel('Date',fontsize=20,color='brown')
# Out:
# Text(0.5, 0, 'Date')

# %%
df_rolling = df[['simple_rtn']].rolling(window=22).aggregate(['mean','std'])


df_rolling.columns = df_rolling.columns.droplevel()
df_outliers = df.join(df_rolling)
def indentify_outliers(row, n_sigmas=3) :
    x = row['simple_rtn']
    mu = row['mean']
    sigma = row['std']
    if (x > mu + 3 * sigma) | (x < mu - 3 * sigma) :
        return 1
    else:
        return 0

# %%
df_outliers['outlier'] = df_outliers.apply(indentify_outliers,axis=1)
outliers = df_outliers.loc[df_outliers['outlier']==1,['simple_rtn']]

fig, ax = plt.subplots(figsize=(18,12))
ax.plot(df_outliers.index,df_outliers.simple_rtn,color='blue',label='Normal')
ax.scatter(outliers.index,outliers.simple_rtn, color='red',label='Anomaly')
ax.set_title("Boeing Company stock returns")
ax.legend(loc='upper left')

# %%
class SmaStrategy (bt.Strategy):    #backtrader strategy
    params = (('ma_period', 20), )  #try running for 25, 30, 45,90 and compare profit
    
    def __init__(self):
        self.data_close = self.datas[0].close
        self.order = None
        self.price = None
        self.comm = None
        self.sma = bt.ind.SMA(self.datas[0],period=self.params.ma_period)
        

    def log(self, txt):
        dt=self.datas[0].datetime.date(0).isoformat()
        print(f'{dt}, {txt}')

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'BUY EXECUTED --- Price:{order.executed.price:.2f},Cost:{order.executed.value:.2f},Commission:{order.executed.comm:.2f}')
                self.price = order.executed.price
                self.comm = order.executed.comm 
            else:
                self.log(f' SELL EXECUTED --- Price:{order.executed.price:.2f},Cost:{order.executed.value:.2f},Commission:{order.executed.comm:.2f}')        
                self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
                    self.log('Order Failed')
        self.order=None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log(f'OPERATION RESULT ---Gross: {trade.pnl:.2f},Net:{trade.pnlcomm:.2f}')

    def next(self):
        if self.order:
            return
        if not self.position:
            if self.datas[0].close[0] > self.sma[0]:
                self.log(f' BUY CREATED --- Price:{self.datas[0].close[0]:.2f}')
                self.order = self.buy()
        else:
            if self.datas[0].close[0] < self.sma[0]:
                    self.log(f' SELL CREATED --- Price:{self.datas[0].close[0]:.2f}')
                    self.order = self.sell()

# %%
# pip install yfinance backtesting

# %%
import yfinance as yf
import backtrader as bt
#xxx
cash = 10000000
commission = 0.001
percentageUsed = 10

cerebro = bt.Cerebro(stdstats=False)
dataw = bt.feeds.PandasData(dataname=yf.download(stock,startdate ,enddate ))
# data = bt.feeds.YahooFinanceData(dataname='GOOG',fromdate=datetime(2021,8,3),todate=datetime(2022,8,4))
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
cerebro.adddata(dataw)
cerebro.broker.setcash(cash)   #cash value is $10M
cerebro.addstrategy(SmaStrategy)
cerebro.broker.setcommission(commission)
cerebro.addsizer(bt.sizers.PercentSizer,percents=percentageUsed)  # only 10% of our portfolio is used
cerebro.addobserver(bt.observers.BuySell)
cerebro.addobserver(bt.observers.Value)

# %%
cerebro.broker.setcash(cash)   #cash value is $10M
cerebro.addstrategy(SmaStrategy)
cerebro.broker.setcommission(commission)
cerebro.addsizer(bt.sizers.PercentSizer,percents=percentageUsed)  # only 10% of our portfolio is used
cerebro.addobserver(bt.observers.BuySell)
cerebro.addobserver(bt.observers.Value)

# %%
print (f'Starting Portfolio Value: {cerebro.broker.getvalue():.2f}')
cerebro.broker.getvalue()
cerebro.run()
print(f'Final Portfolio Value:  {cerebro.broker.getvalue():.2f}')
profit = cerebro.broker.getvalue() - cash
print('+'*50)
print(f'Profit value is : {profit:.2f}')
print('+'*50)
cerebro.plot()

#if ImportError Cannot import name warnings from matplotlib.dates
#pip uninstall backtrader
#pip install git+https://github.com/mementum/backtrader.git@0fa63ef4a35dc53cc7320813f8b15480c8f85517
# Out:
# Starting Portfolio Value: 10000000.00
# 2021-09-22,  BUY CREATED --- Price:216.98
cerebro.broker.setcommission(0)
cerebro.addsizer(bt.sizers.PercentSizer,percents=10)  # only 10% of our portfolio is used
cerebro.addobserver(bt.observers.BuySell)
cerebro.addobserver(bt.observers.Value)
print (f'Starting Portfolio Value: {cerebro.broker.getvalue():.2f}')
cerebro.broker.getvalue()
cerebro.run()
print(f'Final Portfolio Value:  {cerebro.broker.getvalue():.2f}')
profitNocomm = cerebro.broker.getvalue() - cash
comm = profitNocomm - profit
print(f'profit without commission is :{profitNocomm:.2f}')
print('+'*50)
print(f'costs of the transactions is  :{comm:.2f}')
print('+'*50)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Starting Portfolio Value: 10000000.00
# 2021-09-22,  BUY CREATED --- Price:216.98
# 2021-09-23, BUY EXECUTED --- Price:217.81,Cost:1003825.25,Commission:0.00
# 2021-10-14,  SELL CREATED --- Price:217.44
# 2021-10-15,  SELL EXECUTED --- Price:218.17,Cost:1003825.25,Commission:0.00
# 2021-10-15, OPERATION RESULT ---Gross: 1659.14,Net:1659.14
# 2021-11-05,  BUY CREATED --- Price:224.46
# 2021-11-08, BUY EXECUTED --- Price:225.24,Cost:1003641.49,Commission:0.00
# 2021-11-19,  SELL CREATED --- Price:214.13
# 2021-11-22,  SELL EXECUTED --- Price:215.00,Cost:1003641.49,Commission:0.00
# 2021-11-22, OPERATION RESULT ---Gross: -45628.19,Net:-45628.19
# 2021-12-22,  BUY CREATED --- Price:201.69
# 2021-12-23, BUY EXECUTED --- Price:202.13,Cost:997775.08,Commission:0.00
# 2022-01-21,  SELL CREATED --- Price:205.44
# 2022-01-24,  SELL EXECUTED --- Price:199.85,Cost:997775.08,Commission:0.00
# 2022-01-24, OPERATION RESULT ---Gross: -11254.77,Net:-11254.77
# 2022-02-07,  BUY CREATED --- Price:211.92
# 2022-02-08, BUY EXECUTED --- Price:212.68,Cost:998044.05,Commission:0.00
# 2022-02-22,  SELL CREATED --- Price:198.74
# 2022-02-23,  SELL EXECUTED --- Price:201.13,Cost:998044.05,Commission:0.00
# 2022-02-23, OPERATION RESULT ---Gross: -54200.66,Net:-54200.66
# 2022-03-17,  BUY CREATED --- Price:190.19
# 2022-03-18, BUY EXECUTED --- Price:192.07,Cost:998834.26,Commission:0.00
# 2022-03-21,  SELL CREATED --- Price:185.90
# 2022-03-22,  SELL EXECUTED --- Price:185.24,Cost:998834.26,Commission:0.00
# 2022-03-22, OPERATION RESULT ---Gross: -35518.51,Net:-35518.51
# 2022-03-22,  BUY CREATED --- Price:191.04
# 2022-03-23, BUY EXECUTED --- Price:189.67,Cost:978438.40,Commission:0.00
# 2022-03-23,  SELL CREATED --- Price:186.04
# 2022-03-24,  SELL EXECUTED --- Price:186.35,Cost:978438.40,Commission:0.00
# 2022-03-24, OPERATION RESULT ---Gross: -17126.63,Net:-17126.63
# 2022-03-24,  BUY CREATED --- Price:189.05
# 2022-03-25, BUY EXECUTED --- Price:187.76,Cost:977079.99,Commission:0.00
# 2022-04-05,  SELL CREATED --- Price:182.65
# 2022-04-06,  SELL EXECUTED --- Price:180.40,Cost:977079.99,Commission:0.00
# 2022-04-06, OPERATION RESULT ---Gross: -38300.54,Net:-38300.54
# 2022-04-19,  BUY CREATED --- Price:185.98
# 2022-04-20, BUY EXECUTED --- Price:187.24,Cost:986602.21,Commission:0.00
# 2022-04-20,  SELL CREATED --- Price:183.55
# 2022-04-21,  SELL EXECUTED --- Price:188.73,Cost:986602.21,Commission:0.00
# 2022-04-21, OPERATION RESULT ---Gross: 7851.03,Net:7851.03
# 2022-06-02,  BUY CREATED --- Price:140.50
# 2022-06-03, BUY EXECUTED --- Price:138.52,Cost:966926.90,Commission:0.00
# 2022-06-10,  SELL CREATED --- Price:127.00
# 2022-06-13,  SELL EXECUTED --- Price:123.00,Cost:966926.90,Commission:0.00
# 2022-06-13, OPERATION RESULT ---Gross: -108336.05,Net:-108336.05
# 2022-06-15,  BUY CREATED --- Price:133.72
# 2022-06-16, BUY EXECUTED --- Price:131.70,Cost:955262.74,Commission:0.00
# Final Portfolio Value:  9969838.93
# profit without commission is :-30161.07
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# costs of the transactions is  :4330981957691327907235315963172451863925592863917106790400.00
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
# pip install fastquant

# %%
# from __future__ import (absolute_import,division,print_function,unicode_literals,)

# import backtrader as bt
# from datetime import datetime
# from fastquant.strategies.base import BaseStrategy

# class MACDStrategy(BaseStrategy):
#     params = (("fast_period", 12),("slow_period", 26),("signal_period", 9),)
#     def __init__(self):
#         super().__init__()

#         self.fast_period = self.params. fast_period
#         self.slow_period = self.params.slow_period
#         self.signal_period = self.params.signal_period
#         self.commission = self.params.commission

#         if self.strategy_logging:
#             print("===Strategy level arguments===")
#             print("fast_period :", self.fast_period)
#             print("slow_period :", self.slow_period)
#             print("signal_period :", self.signal_period)

#         macd_ind = bt.ind.MACD(
#         period_mel=self.fast_period,
#         period_me2=self.slow_period,
#         period_signal=self.signal_period,)

#         self.macd = macd_ind.macd
#         self.signal = macd_ind.signal
#         self.crossover = bt.ind.CrossOver(self.macd, self.signal)
        
#     def buy_signal(self):
#         return self.crossover > 0

#     def sell_signal(self):
#         return self.crossover < 0

# %%
#MACDStrategy

# cerebro = bt.Cerebro(stdstats=False)
# data = bt.feeds.PandasData(dataname=yf.download(stock, startdate, enddate))
# cerebro.adddata(data)
# cerebro.broker.setcash(cash)   
# cerebro.addstrategy(MACDStrategy)
# cerebro.broker.setcommission(commission)
# cerebro.addsizer(bt.sizers.PercentSizer,percents=10)  
# cerebro.addobserver(bt.observers.BuySell)
# cerebro.addobserver(bt.observers.Value)
# print (f'Starting Portfolio Value: {cerebro.broker.getvalue():.2f}')
# cerebro.broker.getvalue()
# cerebro.run()
# print(f'Final Portfolio Value:  {cerebro.broker.getvalue():.2f}')
# profitNocomm = cerebro.broker.getvalue() - cash
# comm = profitNocomm - profit
# print(f'profit without commission is :{profitNocomm:.2f}')
# print('+'*50)
# print(f'costs of the transactions is  :{comm:.2f}')
# print('+'*50)

# cerebro.plot()

# %%
prev_cash = 10000000
from backtesting.lib import crossover
class MyStrategy (bt.Strategy):    #backtrader strategy
    params = (('p1', 10), ('p2', 20),)  #try running for 25, 30, 45,90 and compare profit
    
    
    def __init__ (self):
        self.order = 0
        self.price = 0
        self.comm = 0
#         self.sma = bt.ind.SMA(self.datas[0],period=self.params.ma_period)
        self.sma = bt.ind.SimpleMovingAverage(self.data0,period=50)
        self.sma1 = bt.ind.SimpleMovingAverage(self.data0,period=self.p.p1)
        self.sma2 = bt.ind.SimpleMovingAverage(self.data0,period=self.p.p2)
        
        

    def log(self, txt):
        dt=self.datas[0].datetime.date(0).isoformat()
        print(f'{dt} | {txt}')

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(cl(f' BUY ORDER EXECUTED!  [Price:{order.executed.price:.2f} - Cost:{order.executed.value:.2f} - Commission:{order.executed.comm:.2f}]',color='green',attrs=['bold']))
                self.price = order.executed.price
                self.comm = order.executed.comm 
            else:
                self.log(cl(f'  SELL ORDER EXECUTED! [Price:{order.executed.price:.2f} - Cost:{order.executed.value:.2f} - Commission:{order.executed.comm:.2f}]',color='red',attrs=['bold']))        
                self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
                    self.log('Order Failed')
        self.order=None
        
    
    def notify_trade(self, trade):
        self.log(cl(f'OPERATION RESULTS: [GROSS PNL: {trade.pnl:.2f} - NET PNL:{trade.pnlcomm:.2f}]',attrs=['bold']))
    
    def notify_fund(self,cash, value, fundvalue, shares):
        global prev_cash
        if(cash == prev_cash):
            return
        else:
            self.log(cl(f'CURRENT FUNDS:   [CASH: {cash:.2f} - VALUE:{value:.2f} - FUND VALUE:{fundvalue:.2f} - SHARES:{shares:.2f}]',attrs=['bold']))
            prev_cash = cash
        
#     
    def next(self):
#             
        if self.position:
            if self.datas[0].close[0] < self.sma[0]:
                    self.log(cl(f'▶ SELL ORDER IS CREATED! Price:{self.datas[0].close[0]:.2f}',color='red',attrs=['bold']))
                    self.order = self.sell()
            
        else:
            if self.datas[0].close[0] > self.sma[0]:
                self.log(cl(f'▶ BUY ORDER IS CREATED!   Price:{self.datas[0].close[0]:.2f}',color='green',attrs=['bold']))
                self.order = self.buy()
                    
#     if self.order:
#             return
#         if not self.position:
#             if (self.sma1 > self.sma2):
#                 self.log(f' BUY CREATED --- Price:{self.data_close[0]:.2f}')
#                 self.order = self.buy()
#         else:
#             if (self.sma2> self.sma1):
#                     self.log(f' SELL CREATED --- Price:{self.data_close[0]:.2f}')
#                     self.order = self.sell()

# %%
import yfinance as yf
import backtrader as bt
#xxx
cash = 10000000
commission = 0.001
percentageUsed = 10
def uselessFunction(uselessArg):
    print('\n')
    print( '+' * 50)
    print('+',' '*46,'+')
    print ('+',' '*4,uselessArg,' '*4,'+')
    print('+',' '*46,'+')
    print('+'*50,'\n')
cerebro = bt.Cerebro(stdstats=False)
dataw = bt.feeds.PandasData(dataname=yf.download(stock,startdate ,enddate ))
# data = bt.feeds.YahooFinanceData(dataname='GOOG',fromdate=datetime(2021,8,3),todate=datetime(2022,8,4))
cerebro.adddata(dataw)
cerebro.broker.setcash(cash)   #cash value is $10M
cerebro.addstrategy(MyStrategy,p1=15,p2=50)
cerebro.broker.setcommission(commission)
cerebro.addsizer(bt.sizers.PercentSizer,percents=percentageUsed)  # only 10% of our portfolio is used
cerebro.addobserver(bt.observers.BuySell)
cerebro.addobserver(bt.observers.Value)
uselessFunction(f'Starting Portfolio Value: {cerebro.broker.getvalue():.2f}')

cerebro.broker.getvalue()
cerebro.run()
print()
uselessFunction(f'Final Portfolio Value:  {cerebro.broker.getvalue():.2f}')
uselessFunction(f'Profit is : {cerebro.broker.getvalue() - cash:.2f}')
cerebro.plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# +                                                +
# +      Starting Portfolio Value: 10000000.00      +
# +                                                +
# ++++++++++++++++++++++++++++++++++++++++++++++++++
#
# 2021-11-05 | ▶ BUY ORDER IS CREATED!   Price:224.46
# 2021-11-08 |  BUY ORDER EXECUTED!  [Price:225.24 - Cost:1003475.00 - Commission:1003.48]
# 2021-11-08 | OPERATION RESULTS: [GROSS PNL: 0.00 - NET PNL:-1003.48]
# 2021-11-08 | CURRENT FUNDS:   [CASH: 8995521.52 - VALUE:9987591.32 - FUND VALUE:99.88 - SHARES:100000.00]
# 2021-11-19 | ▶ SELL ORDER IS CREATED! Price:214.13
# 2021-11-22 |   SELL ORDER EXECUTED! [Price:215.00 - Cost:1003475.00 - Commission:957.85]
# 2021-11-22 | OPERATION RESULTS: [GROSS PNL: -45620.62 - NET PNL:-47581.95]
# 2021-11-22 | CURRENT FUNDS:   [CASH: 9952418.05 - VALUE:9952418.05 - FUND VALUE:99.52 - SHARES:100000.00]
# 2022-01-04 | ▶ BUY ORDER IS CREATED!   Price:213.63
# 2022-01-05 |  BUY ORDER EXECUTED!  [Price:216.64 - Cost:1009264.52 - Commission:1009.26]
# 2022-01-05 | OPERATION RESULTS: [GROSS PNL: 0.00 - NET PNL:-1009.26]
# 2022-01-05 | CURRENT FUNDS:   [CASH: 8942144.26 - VALUE:9934777.20 - FUND VALUE:99.35 - SHARES:100000.00]
# 2022-01-21 | ▶ SELL ORDER IS CREATED! Price:205.44
# 2022-01-24 |   SELL ORDER EXECUTED! [Price:199.85 - Cost:1009264.52 - Commission:931.04]
# 2022-01-24 | OPERATION RESULTS: [GROSS PNL: -78219.83 - NET PNL:-80160.14]
# 2022-01-24 | CURRENT FUNDS:   [CASH: 9872257.91 - VALUE:9872257.91 - FUND VALUE:98.72 - SHARES:100000.00]
# 2022-02-01 | ▶ BUY ORDER IS CREATED!   Price:208.34
# 2022-02-02 |  BUY ORDER EXECUTED!  [Price:205.43 - Cost:973436.64 - Commission:973.44]
# 2022-02-02 | OPERATION RESULTS: [GROSS PNL: 0.00 - NET PNL:-973.44]
# 2022-02-02 | CURRENT FUNDS:   [CASH: 8897847.82 - VALUE:9881188.06 - FUND VALUE:98.81 - SHARES:100000.00]
# 2022-02-22 | ▶ SELL ORDER IS CREATED! Price:198.74
# 2022-02-23 |   SELL ORDER EXECUTED! [Price:201.13 - Cost:973436.64 - Commission:953.06]
# 2022-02-23 | OPERATION RESULTS: [GROSS PNL: -20375.63 - NET PNL:-22302.13]
# 2022-02-23 | CURRENT FUNDS:   [CASH: 9849955.78 - VALUE:9849955.78 - FUND VALUE:98.50 - SHARES:100000.00]
# 2022-07-01 | ▶ BUY ORDER IS CREATED!   Price:139.84
# 2022-07-05 |  BUY ORDER EXECUTED!  [Price:136.25 - Cost:959708.60 - Commission:959.71]
# 2022-07-05 | OPERATION RESULTS: [GROSS PNL: 0.00 - NET PNL:-959.71]
# 2022-07-05 | CURRENT FUNDS:   [CASH: 8889287.47 - VALUE:9859209.46 - FUND VALUE:98.59 - SHARES:100000.00]
# 2022-07-06 | ▶ SELL ORDER IS CREATED! Price:136.31
# 2022-07-07 |   SELL ORDER EXECUTED! [Price:137.93 - Cost:959708.60 - Commission:971.54]
# 2022-07-07 | OPERATION RESULTS: [GROSS PNL: 11833.42 - NET PNL:9902.17]
# 2022-07-07 | CURRENT FUNDS:   [CASH: 9859857.95 - VALUE:9859857.95 - FUND VALUE:98.60 - SHARES:100000.00]
# 2022-07-07 | ▶ BUY ORDER IS CREATED!   Price:139.97
# 2022-07-08 |  BUY ORDER EXECUTED!  [Price:139.70 - Cost:984083.81 - Commission:984.08]
# 2022-07-08 | OPERATION RESULTS: [GROSS PNL: 0.00 - NET PNL:-984.08]
# 2022-07-08 | CURRENT FUNDS:   [CASH: 8874790.05 - VALUE:9854436.05 - FUND VALUE:98.54 - SHARES:100000.00]
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# +                                                +
# +      Final Portfolio Value:  10065411.77      +
# +                                                +
# ++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# +                                                +
# +      Profit is : 65411.77      +
# +                                                +
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# <img src="data:image/png;base64,..." width="432">
# [[<Figure size 432x288 with 3 Axes>]]

# %%
import backtrader as bt
class MySignal(bt.Indicator):
    lines = ('signal',)
    params = (('period', 30),)

    def __init__(self):
        self.lines.signal = self.data0 - bt.indicators.SMA(period=self.p.period)

# %%
data = bt.feeds.PandasData(dataname=yf.download(stock,startdate ,enddate ))
cerebro.adddata(data)

cerebro.add_signal(bt.SIGNAL_LONGSHORT, MySignal)
cerebro.run()
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 5>()
#       2 cerebro.adddata(data)
#       4 cerebro.add_signal(bt.SIGNAL_LONGSHORT, MySignal)
# ----> 5 cerebro.run()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\backtrader\cerebro.py:1098, in Cerebro.run(self, **kwargs)
#    1095 if signalst is None:
#    1096     # Try to see if the 1st regular strategy is a signal strategy
#    1097     try:
# -> 1098         signalst, sargs, skwargs = self.strats.pop(0)
#    1099     except IndexError:
#    1100         pass  # Nothing there
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
# pip install bokeh echo backtrader bt ffn yfinance

# %%
import bt
 # fetch some data
data = bt.get('spy,agg', start='2010-01-01')
data.head()

# %%
import ffn
returns = ffn.get('BA,aapl,msft,TSLA', start='2010-01-01').to_returns().dropna()
returns.calc_mean_var_weights().as_format('.2%')

# %%
# create the strategy
s = bt.Strategy('s1', [bt.algos.RunMonthly(),
                       bt.algos.SelectAll(),
                       bt.algos.WeighEqually(),
                       bt.algos.Rebalance()])

# %%
# create a backtest and run it
test = bt.Backtest(s, data)
res = bt.run(test)

# %%
res.plot()

# %%
res.display()

# %%
res.plot_histogram()

# %%
res.plot_security_weights()

# %%
from backtesting import Backtest, Strategy
from backtesting.lib import crossover

from backtesting.test import SMA


class SmaCross(Strategy):
    n1 = 5
    n2 = 20

    def init(self):
        close = self.data.Close
        self.sma1 = self.I(SMA, close, self.n1)
        self.sma2 = self.I(SMA, close, self.n2)

    def next(self):
        if crossover(self.sma1, self.sma2):
            self.buy()
        elif crossover(self.sma2, self.sma1):
            self.sell()


bt = Backtest(ba, SmaCross,
              cash=cash/10, commission=commission,
              exclusive_orders=True)

output = bt.run()

bt.plot()

# %%
pip install ta-lib

# %%
import numpy
import talib

close = numpy.random.random(100)

# %%
output = talib.SMA(close)

# %%
from talib import MA_Type

upper, middle, lower = talib.BBANDS(close, matype=MA_Type.T3)

# %%
output = talib.MOM(close, timeperiod=5)

# %%
from backtesting import Backtest, Strategy
from backtesting.lib import crossover
#https://www.newtraderu.com/2022/05/14/moving-average-crossover-backtest-results/#:~:text=How%20do%20you%20do%20a,or%20break%20below%20each%20other.
from backtesting.test import SMA

class SmaCross(Strategy):
    n1 = 5
    n2 = 20

    def init(self):
        close = self.data.Close
        self.sma1 = self.I(SMA, close, self.n1)
        self.sma2 = self.I(SMA, close, self.n2)

    def next(self):
        if crossover(self.sma1, self.sma2):
            self.buy()
        elif crossover(self.sma2, self.sma1):
            self.sell()


bt = Backtest(ba, SmaCross,
              cash=cash/10, commission=commission,
              exclusive_orders=True)



output = bt.run()
bt.plot()

# %%
ba.tail()

# %%
import pandas as pd


def SMA(values, n):
    """
    Return simple moving average of `values`, at
    each step taking into account `n` previous values.
    """
    return pd.Series(values).rolling(n).mean()

# %%
from backtesting import Strategy
from backtesting.lib import crossover


class SmaCross(Strategy):
    # Define the two MA lags as *class variables*
    # for later optimization
    n1 = 5
    n2 = 20
    
    def init(self):
        # Precompute the two moving averages
        self.sma1 = self.I(SMA, self.data.Close, self.n1)
        self.sma2 = self.I(SMA, self.data.Close, self.n2)
    
    def next(self):
        # If sma1 crosses above sma2, close any existing
        # short trades, and buy the asset
        if crossover(self.sma1, self.sma2):
            self.position.close()
            self.buy()

        # Else, if sma1 crosses below sma2, close any existing
        # long trades, and sell the asset
        elif crossover(self.sma2, self.sma1):
            self.position.close()
            self.sell()
            
bt = Backtest(ba, SmaCross,
              cash=cash/10, commission=commission,
              exclusive_orders=True)



output = bt.run()
bt.plot()

# %%
from backtesting import Backtest

bt = Backtest(ba, SmaCross, cash=cash/10, commission=commission)
stats = bt.run()
stats

# %%
bt.plot()

# %%
# %%time

stats = bt.optimize(n1=range(5, 30, 5),
                    n2=range(10, 70, 5),
                    maximize='Equity Final [$]',
                    constraint=lambda param: param.n1 < param.n2)

# %%
stats

# %%
stats._strategy

# %%
bt.plot(plot_volume=False, plot_pl=False)

# %%
stats.tail()

# %%
stats['_equity_curve']

# %%
stats['_trades']
